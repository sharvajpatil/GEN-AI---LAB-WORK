# %%
pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 3.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# ...

# %%
from datasets import load_dataset

# %%
dataset = load_dataset("foldl/MathSet")
# Out:
# ...
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# ...
# Generating train split:   0%|          | 0/1127 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Q', 'S', 'A'],
#         num_rows: 1127
#     })
# })

# %%
converted = load_dataset("csv", data_files = "/content/sample_data/california_housing_train.csv")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
converted
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value'],
#         num_rows: 17000
#     })
# })

# %%
type(dataset)
# Out:
# datasets.dataset_dict.DatasetDict

# %%
dataset['train']
# Out:
# Dataset({
#     features: ['Q', 'S', 'A'],
#     num_rows: 1127
# })

# %%
dataset['train'].to_pandas()
# Out:
#                                                       Q  ...            A
# 0     В обменном пункте 1 гривна стоит 3 рубля 70 ко...  ...    Ответ: 44
# 1     По тарифному плану «Просто как день» компания ...  ...    Ответ: 43
# 2     На одну порцию рисовой каши требуется 40 грамм...  ...    Ответ: 22
# 3     Ананасы стоят 85 руб. за штуку. Какое максимал...  ...     Ответ: 7
# 4     Стоимость проезда в маршрутном такси составляе...  ...     Ответ: 8
# ...                                                 ...  ...          ...
# 1122  <img src="/get_file?id=261" style="float:right...  ...     Ответ: 2
# 1123  В таблице показано количество билетов и возмож...  ...  Ответ: 34,5
# 1124  В таблице показано распределение случайной вел...  ...   Ответ: 0,5
# 1125  Монету подбрасывают до тех пор, пока орёл не в...  ...     Ответ: 4
# 1126  Монету подбрасывают 8 раз. Найдите математичес...  ...     Ответ: 4
#
# [1127 rows x 3 columns]
